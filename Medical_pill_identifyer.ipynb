# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
# Clone the YOLOv5 repository from GitHub
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16575, done.
# remote: Counting objects: 100% (53/53), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 16575 (delta 28), reused 37 (delta 18), pack-reused 16522
# Receiving objects: 100% (16575/16575), 15.03 MiB | 24.40 MiB/s, done.
# Resolving deltas: 100% (11387/11387), done.

# %%
# Change directory to the yolov5 folder
# !cd yolov5

# Install the requirements specified in the requirements.txt file located in the yolov5 folder
# !pip install -r /content/yolov5/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 6.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 31.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.0/755.0 kB 46.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 10.7 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...

# %%
# Load the YOLOv5 model ('yolov5s') from the 'ultralytics/yolov5' repository using Torch Hub
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/hub.py:294: UserWarning: You are about to download and run code from an untrusted repository. In a future release, this won't be allowed. To add the repository to your trusted list, change the command to {calling_fn}(..., trust_repo=False) and a command prompt will appear asking for an explicit confirmation of trust, or load(..., trust_repo=True), which will assume that the prompt is to be answered with 'yes'. You can also use load(..., trust_repo='check') which will only prompt for confirmation if the repo is not already trusted. This will eventually be the default behaviour
#   warnings.warn(
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /root/.cache/torch/hub/master.zip
# YOLOv5 🚀 2024-5-1 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# ...
# 100%|██████████| 14.1M/14.1M [00:00<00:00, 245MB/s]
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# ...

# %%
model
# Out:
# AutoShape(
#   (model): DetectMultiBackend(
#     (model): DetectionModel(
#       (model): Sequential(
#         (0): Conv(
#           (conv): Conv2d(3, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (2): C3(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
# ...

# %%
import torch

# %%
# !pip install ipywidgets
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 19.6 MB/s eta 0:00:00
# ...

# %%
from IPython.display import Image, display, clear_output
clear_output()

# %%
# unzipping the train_data folder
# !unzip -q /content/train_data.zip

# %%
# Run YOLOv5 training script with specified parameters
# !python /content/yolov5/train.py --img 640 --batch 3 --epoch 60 --data custom_data.yaml --weights yolov5s.pt --nosave --cache

    # --img 640 \                    # Set input image size to 640x640 pixels
    # --batch 4 \                    # Set batch size to 5
    # --epoch 70 \                   # Set the number of training epochs to 60
    # --data custom_data.yaml \      # Specify the path to the custom data configuration file
    # --weights yolov5s.pt \         # Specify the path to the initial weights file
    # --nosave \                     # Do not save any checkpoints during training
    # --cache                        # Cache images for faster training
# Out:
# 2024-04-27 16:38:31.674546: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-27 16:38:31.674633: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-27 16:38:31.676311: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python /content/yolov5/detect.py --weights yolov5/runs/train/exp2/weights/last.pt --img 650 --conf 0.35 --source /content/video.mp4
#  --weights yolov5/runs/train/exp2/weights/last.pt \  # Specify the path to the trained model weights
#     --img 650 \                                          # Set input image size to 650x650 pixels
#     --conf 0.35 \                                        # Set confidence threshold for detections to 0.35
#     --source /content/video.mp4                           # Specify the path to the input video file
# Out:
# detect: weights=['yolov5/runs/train/exp2/weights/last.pt'], source=/content/video.mp4, data=yolov5/data/coco128.yaml, imgsz=[650, 650], conf_thres=0.35, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-305-g4456c953 Python-3.10.12 torch-2.2.1+cu121 CPU
#
# Traceback (most recent call last):
#   File "/content/yolov5/detect.py", line 312, in <module>
#     main(opt)
#   File "/content/yolov5/detect.py", line 307, in main
#     run(**vars(opt))
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py", line 115, in decorate_context
#     return func(*args, **kwargs)
#   File "/content/yolov5/detect.py", line 115, in run
# ...
